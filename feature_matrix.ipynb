# %%
import pandas as pd
import numpy as np
columns = []
tableData = []

# %%
student_registration = pd.read_csv("data/studentRegistration.csv")

# %%
student_registration.head(5)
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
studentRegistration = student_registration[(student_registration.code_module == 'AAA') & (student_registration.code_presentation == '2013J')]
studentIdColumn = 'id_student'
studentId = studentRegistration[[studentIdColumn]]
columns = [studentIdColumn]
tableData=studentId
tableData.head(5)
# Out:
#    id_student
# 0       11391
# 1       28400
# 2       30268
# 3       31604
# 4       32885

# %%
tableData.count()
# Out:
# id_student    383
# dtype: int64

# %%
assesments = pd.read_csv("data/assessments.csv")
assesments = assesments[(assesments.code_module == 'AAA') & (assesments.code_presentation == '2013J')]
assesmentIdColumn = 'id_assessment'
assesmentIds = assesments[assesmentIdColumn]
assesmentIds
# Out:
# 0    1752
# 1    1753
# 2    1754
# 3    1755
# 4    1756
# 5    1757
# Name: id_assessment, dtype: int64

# %%
for i in range(len(assesmentIds)): 
    columns.append(assesmentIds[i])

# %%
featureTable = pd.DataFrame(data =tableData, columns = columns)
featureTable
# Out:
#      id_student  1752  1753  1754  1755  1756  1757
# 0         11391   NaN   NaN   NaN   NaN   NaN   NaN
# 1         28400   NaN   NaN   NaN   NaN   NaN   NaN
# 2         30268   NaN   NaN   NaN   NaN   NaN   NaN
# 3         31604   NaN   NaN   NaN   NaN   NaN   NaN
# 4         32885   NaN   NaN   NaN   NaN   NaN   NaN
# 5         38053   NaN   NaN   NaN   NaN   NaN   NaN
# 6         45462   NaN   NaN   NaN   NaN   NaN   NaN
# 7         45642   NaN   NaN   NaN   NaN   NaN   NaN
# 8         52130   NaN   NaN   NaN   NaN   NaN   NaN
# 9         53025   NaN   NaN   NaN   NaN   NaN   NaN
# 10        57506   NaN   NaN   NaN   NaN   NaN   NaN
# 11        58873   NaN   NaN   NaN   NaN   NaN   NaN
# 12        59185   NaN   NaN   NaN   NaN   NaN   NaN
# 13        62155   NaN   NaN   NaN   NaN   NaN   NaN
# 14        63400   NaN   NaN   NaN   NaN   NaN   NaN
# 15        65002   NaN   NaN   NaN   NaN   NaN   NaN
# 16        70464   NaN   NaN   NaN   NaN   NaN   NaN
# 17        71361   NaN   NaN   NaN   NaN   NaN   NaN
# 18        74372   NaN   NaN   NaN   NaN   NaN   NaN
