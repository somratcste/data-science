# %%
import pandas as pd

# %%
student_info = pd.read_csv("data/studentInfo.csv")

# %%
student_info.head(5)
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# 2               60          Y    Withdrawn
# 3               60          N         Pass
# 4               60          N         Pass

# %%
student_info['gender'].head(5)
# Out:
# 0    M
# 1    F
# 2    F
# 3    F
# 4    F
# Name: gender, dtype: object

# %%
student_info[student_info.gender == 'F'].head(5)
# Out:
#   code_module code_presentation  id_student gender                region  \
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
# 7         AAA             2013J       45642      F  North Western Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
# 7  A Level or Equivalent  90-100%     0-35                     0
#
#    studied_credits disability final_result
# 1               60          N         Pass
# 2               60          Y    Withdrawn
# 3               60          N         Pass
# 4               60          N         Pass
# 7              120          N         Pass

# %%
femaleStudents = student_info[student_info.gender == 'F'].head(5)

# %%
femaleStudents[['gender','region']].head(5)
# Out:
#   gender                region
# 1      F              Scotland
# 2      F  North Western Region
# 3      F     South East Region
# 4      F  West Midlands Region
# 7      F  North Western Region

# %%
student_registration = pd.read_csv("data/studentRegistration.csv")

# %%
student_registration.head(5)
# Out:
#   code_module code_presentation  id_student date_registration  \
# 0         AAA             2013J       11391              -159
# 1         AAA             2013J       28400               -53
# 2         AAA             2013J       30268               -92
# 3         AAA             2013J       31604               -52
# 4         AAA             2013J       32885              -176
#
#   date_unregistration
# 0                   ?
# 1                   ?
# 2                  12
# 3                   ?
# 4                   ?

# %%
studentsMoreThan28Days=student_registration[student_registration.date_unregistration > '28']

# %%
studentsMoreThan28Days.head(5)
# Out:
#   code_module code_presentation  id_student date_registration  \
# 0         AAA             2013J       11391              -159
# 1         AAA             2013J       28400               -53
# 3         AAA             2013J       31604               -52
# 4         AAA             2013J       32885              -176
# 5         AAA             2013J       38053              -110
#
#   date_unregistration
# 0                   ?
# 1                   ?
# 3                   ?
# 4                   ?
# 5                   ?

# %%
studentsOnlyNullValuesofDateUnregistration = student_registration[student_registration.date_unregistration == '?']

# %%
studentsOnlyNullValuesofDateUnregistration.head(5)
# Out:
#   code_module code_presentation  id_student date_registration  \
# 0         AAA             2013J       11391              -159
# 1         AAA             2013J       28400               -53
# 3         AAA             2013J       31604               -52
# 4         AAA             2013J       32885              -176
# 5         AAA             2013J       38053              -110
#
#   date_unregistration
# 0                   ?
# 1                   ?
# 3                   ?
# 4                   ?
# 5                   ?

# %%
registeredStudents = studentsMoreThan28Days | studentsOnlyNullValuesofDateUnregistration
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# H:\Python\anaconda\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# TypeError: unsupported operand type(s) for |: 'str' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-02f98fb981ba> in <module>
# ----> 1 registeredStudents = studentsMoreThan28Days | studentsOnlyNullValuesofDateUnregistration
#
# H:\Python\anaconda\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    2021             # Another DataFrame
#    2022             pass_op = op if should_series_dispatch(self, other, op) else na_op
# -> 2023             return self._combine_frame(other, pass_op, fill_value, level)
#    2024         elif isinstance(other, ABCSeries):
#    2025             # For these values of `axis`, we end up dispatching to Series op,
#
# H:\Python\anaconda\lib\site-packages\pandas\core\frame.py in _combine_frame(self, other, func, fill_value, level)
#    5086         if ops.should_series_dispatch(this, other, func):
#    5087             # iterate over columns
# -> 5088             return ops.dispatch_to_series(this, other, _arith_op)
#    5089         else:
#    5090             result = _arith_op(this.values, other.values)
#
# H:\Python\anaconda\lib\site-packages\pandas\core\ops.py in dispatch_to_series(left, right, func, str_rep, axis)
#    1155         raise NotImplementedError(right)
#    1156
# -> 1157     new_data = expressions.evaluate(column_op, str_rep, left, right)
#    1158
#    1159     result = left._constructor(new_data, index=left.index, copy=False)
#
# H:\Python\anaconda\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     206     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#     210
#
# H:\Python\anaconda\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     121
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#     125     return result
#
# H:\Python\anaconda\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      66         _store_test_result(False)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#      70
#
# H:\Python\anaconda\lib\site-packages\pandas\core\ops.py in column_op(a, b)
#    1133         def column_op(a, b):
#    1134             return {i: func(a.iloc[:, i], b.iloc[:, i])
# -> 1135                     for i in range(len(a.columns))}
#    1136
#    1137     elif isinstance(right, ABCSeries) and axis == "columns":
#
# H:\Python\anaconda\lib\site-packages\pandas\core\ops.py in <dictcomp>(.0)
#    1133         def column_op(a, b):
#    1134             return {i: func(a.iloc[:, i], b.iloc[:, i])
# -> 1135                     for i in range(len(a.columns))}
#    1136
#    1137     elif isinstance(right, ABCSeries) and axis == "columns":
#
# H:\Python\anaconda\lib\site-packages\pandas\core\frame.py in _arith_op(left, right)
#    5082             # left._binop(right, func, fill_value=fill_value)
#    5083             left, right = ops.fill_binop(left, right, fill_value)
# -> 5084             return func(left, right)
#    5085
#    5086         if ops.should_series_dispatch(this, other, func):
#
# H:\Python\anaconda\lib\site-packages\pandas\core\ops.py in wrapper(self, other)
#    1848         filler = (fill_int if is_self_int_dtype and is_other_int_dtype
#    1849                   else fill_bool)
# -> 1850         res_values = na_op(self.values, ovalues)
#    1851         unfilled = self._constructor(res_values,
#    1852                                      index=self.index, name=res_name)
#
# H:\Python\anaconda\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1795                 x = ensure_object(x)
#    1796                 y = ensure_object(y)
# -> 1797                 result = libops.vec_binop(x, y, op)
#    1798             else:
#    1799                 # let null fall thru
#
# pandas/_libs/ops.pyx in pandas._libs.ops.vec_binop()
#
# pandas/_libs/ops.pyx in pandas._libs.ops.vec_binop()
#
# TypeError: unsupported operand type(s) for |: 'str' and 'bool'
