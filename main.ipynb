# %%
import pandas as pd

# %%
student_info = pd.read_csv("data/studentInfo.csv")

# %%
student_info.head(5)
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %%
student_info['gender'].head(5)
# Out:
# 0    M
# 1    F
# 2    F
# 3    F
# 4    F
# Name: gender, dtype: object

# %%
student_info[student_info.gender == 'F'].head(5)
# Out:
#   code_module code_presentation  id_student gender                region  \
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
# 7         AAA             2013J       45642      F  North Western Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
# 7  A Level or Equivalent  90-100%     0-35                     0
#
#    studied_credits disability final_result
# 1               60          N         Pass
# 2               60          Y    Withdrawn
# ...

# %%
femaleStudents = student_info[student_info.gender == 'F'].head(5)

# %%
femaleStudents[['gender','region']].head(5)
# Out:
#   gender                region
# 1      F              Scotland
# 2      F  North Western Region
# 3      F     South East Region
# 4      F  West Midlands Region
# 7      F  North Western Region

# %%
student_registration = pd.read_csv("data/studentRegistration.csv")

# %%
student_registration.head(5)
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
studentsMoreThan28Days=student_registration[student_registration.date_unregistration > 28]

# %%
studentsMoreThan28Days.head(5)
# Out:
#    code_module code_presentation  id_student  date_registration  \
# 15         AAA             2013J       65002             -180.0
# 22         AAA             2013J       94961             -170.0
# 29         AAA             2013J      106247                5.0
# 41         AAA             2013J      129955             -197.0
# 44         AAA             2013J      135335              -29.0
#
#     date_unregistration
# 15                 96.0
# 22                 72.0
# 29                175.0
# 41                135.0
# 44                 30.0

# %%
studentsOnlyNullValuesofDateUnregistration = student_registration[student_registration.date_unregistration.isnull()]

# %%
studentsOnlyNullValuesofDateUnregistration.count()
# Out:
# code_module            22521
# code_presentation      22521
# id_student             22521
# date_registration      22515
# date_unregistration        0
# dtype: int64

# %%
registeredStudents = student_registration[(student_registration.date_unregistration > 28) | (student_registration.date_unregistration.isnull())]

# %%
registeredStudents.head(5)
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
# 5         AAA             2013J       38053             -110.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN

# %%
registeredStudents.count()
# Out:
# code_module            27538
# code_presentation      27538
# id_student             27538
# date_registration      27531
# date_unregistration     5017
# dtype: int64

# %%
student_vle = pd.read_csv("data/studentVle.csv")

# %%
student_vle.head()
# Out:
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
student28Days=student_vle[student_vle.date == 28]

# %%
student28Days[['id_student','code_module','code_presentation']].head(5)
# Out:
#        id_student code_module code_presentation
# 44516     2364471         AAA             2013J
# 44517     2364471         AAA             2013J
# 44518     2364471         AAA             2013J
# 44519     2364471         AAA             2013J
# 44520     2364471         AAA             2013J

# %%
student28Days.set_index(['id_student','code_module','code_presentation']).head(5)
# Out:
#                                           id_site  date  sum_click
# id_student code_module code_presentation
# 2364471    AAA         2013J               546657    28          4
#                        2013J               546879    28          1
#                        2013J               546684    28          3
#                        2013J               546657    28          5
#                        2013J               546659    28          1

# %%
activeStudents = student28Days.set_index(['id_student','code_module','code_presentation']).drop_duplicates()

# %%
activeStudents.head(5)
# Out:
#                                           id_site  date  sum_click
# id_student code_module code_presentation
# 2364471    AAA         2013J               546657    28          4
#                        2013J               546879    28          1
#                        2013J               546684    28          3
#                        2013J               546657    28          5
#                        2013J               546659    28          1

# %%
activeStudents.count()
# Out:
# id_site      7118
# date         7118
# sum_click    7118
# dtype: int64

# %%
assesments = pd.read_csv("data/assessments.csv")

# %%
assesments.head(5)
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0

# %%
TMAAssessmentType = assesments[assesments.assessment_type == 'TMA']

# %%
TMAAssessmentType
# Out:
#     code_module code_presentation  id_assessment assessment_type   date  \
# 0           AAA             2013J           1752             TMA   19.0
# 1           AAA             2013J           1753             TMA   54.0
# 2           AAA             2013J           1754             TMA  117.0
# 3           AAA             2013J           1755             TMA  166.0
# 4           AAA             2013J           1756             TMA  215.0
# 6           AAA             2014J           1758             TMA   19.0
# 7           AAA             2014J           1759             TMA   54.0
# 8           AAA             2014J           1760             TMA  117.0
# 9           AAA             2014J           1761             TMA  166.0
# 10          AAA             2014J           1762             TMA  215.0
# 17          BBB             2013B          14984             TMA   19.0
# 18          BBB             2013B          14985             TMA   47.0
# ...
